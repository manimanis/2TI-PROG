# %%
import pandas as pd

# %%
df = pd.read_csv('bitcoin.csv', decimal=',')
df
# Out:
#           Date  Dernier      Ouv   Plus Haut  Plus Bas      Vol  Variation %
# 0   03/05/2024  61780.6  59104.3     61949.5   58830.8   91,71K         4.50
# 1   02/05/2024  59121.3  58334.9     59548.0   56989.8   98,06K         1.35
# 2   01/05/2024  58331.2  60665.0     60827.5   56643.5  171,55K        -3.85
# 3   30/04/2024  60666.6  63852.4     64700.2   59228.7  121,04K        -5.00
# 4   29/04/2024  63860.1  63113.7     64193.1   61837.2   67,26K         1.19
# 5   28/04/2024  63109.7  63457.9     64346.1   62827.8   36,65K        -0.55
# 6   27/04/2024  63456.8  63765.8     63916.7   62507.7   45,34K        -0.49
# 7   26/04/2024  63766.4  64497.1     64771.3   63354.9   61,60K        -1.13
# 8   25/04/2024  64497.1  64287.1     65247.5   62889.2   80,77K         0.33
# 9   24/04/2024  64285.7  66414.9     67060.5   63606.9   77,83K        -3.21
# 10  23/04/2024  66415.0  66829.5     67180.0   65848.3   52,42K        -0.62
# ...

# %%
df.dtypes
# Out:
# Date            object
# Dernier        float64
# Ouv            float64
#  Plus Haut     float64
# Plus Bas       float64
# Vol             object
# Variation %    float64
# dtype: object

# %%
list(int(cours) for cours in df.Dernier)
# Out:
# [61780,
#  59121,
#  58331,
#  60666,
#  63860,
#  63109,
#  63456,
#  63766,
#  64497,
#  64285,
#  66415,
#  66829,
#  64940,
#  64961,
#  63799,
#  63481,
#  61278,
#  63805,
#  63411,
#  65697,
#  63849,
#  67151,
#  70011,
#  70622,
#  69148,
#  71630,
#  69360,
#  68890,
#  67830,
#  68496,
#  65963]

# %%
df.describe(
)
# Out:
#             Dernier           Ouv     Plus Haut      Plus Bas  Variation %
# count     31.000000     31.000000     31.000000     31.000000    31.000000
# mean   65175.800000  65295.180645  66563.000000  63436.093548    -0.149677
# std     3282.767076   3221.485040   3245.374511   3445.466421     2.737195
# min    58331.200000  58334.900000  59548.000000  56643.500000    -5.000000
# 25%    63469.100000  63623.150000  64398.800000  61390.550000    -2.170000
# 50%    64497.100000  64940.100000  65758.200000  63131.700000     0.330000
# 75%    67491.250000  67483.950000  68965.500000  65838.800000     1.690000
# max    71630.100000  71627.300000  72710.800000  69586.100000     4.500000
